# %%
import pandas as pd 
dateparse = lambda x: pd.datetime.strptime(x, '%d/%m/%Y')

ally = pd.read_csv('data/ally.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
axp = pd.read_csv('data/axp.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
bac = pd.read_csv('data/bac.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
bbt = pd.read_csv('data/bbt.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
bbva = pd.read_csv('data/bbva.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
bcs = pd.read_csv('data/bcs.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
bk = pd.read_csv('data/bk.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
bku = pd.read_csv('data/bku.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
cfg = pd.read_csv('data/cfg.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
citi = pd.read_csv('data/citi.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
cof = pd.read_csv('data/cof.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
dfs = pd.read_csv('data/dfs.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
fbp = pd.read_csv('data/fbp.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
fmbi = pd.read_csv('data/fmbi.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
gs = pd.read_csv('data/gs.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
hsbc = pd.read_csv('data/hsbc.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
jpm = pd.read_csv('data/jpm.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
ms = pd.read_csv('data/ms.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
pnc = pd.read_csv('data/pnc.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
schw = pd.read_csv('data/schw.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
snv = pd.read_csv('data/snv.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
sti = pd.read_csv('data/sti.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
stt = pd.read_csv('data/stt.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
td = pd.read_csv('data/td.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
usb = pd.read_csv('data/usb.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)
wfc = pd.read_csv('data/wfc.csv', index_col="Date", usecols=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Rate"],
        parse_dates=["Date"], date_parser=dateparse)

# %%
ds = [ally, axp, bac, bbt,bbva,bcs,bk,bku,cfg,citi,cof,dfs,fbp,fmbi,gs,hsbc,jpm,ms,pnc,schw,snv,sti,stt,td,usb,wfc]

# %%
for i in ds:
    print(i['Rate'].unique())
# Out:
# ['B1' 'Ba3']
# ['A1' 'A2' 'A3']
# ['A2' 'A1' 'Aa3' 'Aa2' 'Aa1' 'Baa1' 'Baa2' 'A3']
# ['A2' 'A1' 'Aa3']
# ['A1' 'Aa3' 'A2' 'A3' 'Baa2' 'Baa3']
# ['Aaa' 'Aa1' 'Aa2' 'Aa3' 'A2' 'A1']
# ['Aa1' 'Aa3' 'A2' 'A1' 'Aa2' 'Aaa']
# ['Baa3' 'Ba1']
# ['A3' 'Baa1']
# ['Aaa' 'Aa1' 'Aa2' 'A1' 'A2' 'Aa3' 'A3']
# ['Ba1' 'Baa3' 'Baa1' 'A3']
# ['Baa2' 'Baa3']
# ['Baa2' 'Ba1' 'Ba2' 'B1' 'B3' 'Caa2' 'Caa1']
# ['A3' 'A2' 'Baa1' 'Baa2']
# ['A1' 'Aa3' 'A3' 'Baa1']
# ['A1' 'Aa3' 'Aa2']
# ['A2' 'A1' 'Aa3' 'Aa2' 'A3']
# ['Aa3' 'A1' 'A2' 'Baa1' 'Baa2' 'A3']
# ['A2' 'A1' 'A3']
# ['A3' 'A2']
# ['A3' 'A2' 'A1' 'Ba3' 'B1' 'Ba2' 'Ba1']
# ['A1' 'Aa3' 'Baa1']
# ['A1' 'Aa3' 'A2']
# ['Baa1' 'A3' 'A2' 'A1' 'Aa2' 'Aa3' 'Aa1']
# ['A2' 'A1' 'Aa3' 'Aa2']
# ['Aa3' 'Aa2' 'Aa1' 'A1' 'A2']

# %%
for i in ds:
    i['Rate'] = i['Rate'].map({'C':21,'Ca':20,'Caa3':19,'Caa2':18,'Caa1':17,'B3':16,'B2':15,'B1':14,'Ba3':13,'Ba2':12,'Ba1':11,'Baa3':10,'Baa2':9,'Baa1':8,'A3':7,'A2':6,'A1':5,'Aa3':4,'Aa2':3,'Aa1':2,'Aaa':1})

# %%
for i in ds:
    print(i['Rate'].unique())
# Out:
# [14 13]
# [5 6 7]
# [6 5 4 3 2 8 9 7]
# [6 5 4]
# [ 5  4  6  7  9 10]
# [1 2 3 4 6 5]
# [2 4 6 5 3 1]
# [10 11]
# [7 8]
# [1 2 3 5 6 4 7]
# [11 10  8  7]
# [ 9 10]
# [ 9 11 12 14 16 18 17]
# [7 6 8 9]
# [5 4 7 8]
# [5 4 3]
# [6 5 4 3 7]
# [4 5 6 8 9 7]
# [6 5 7]
# [7 6]
# [ 7  6  5 13 14 12 11]
# [5 4 8]
# [5 4 6]
# [8 7 6 5 3 4 2]
# [6 5 4 3]
# [4 3 2 5 6]

# %%
hsbc.head()
# Out:
#                Open     High     Low    Close  Adj Close  Volume  Rate
# Date
# 1999-07-16  62.1250  62.3125  61.625  62.0625  25.404514  231400     5
# 1999-07-19  63.6250  63.6875  61.500  62.1875  25.455683  158200     5
# 1999-07-20  61.7500  61.7500  60.750  60.8750  24.918421   79400     5
# 1999-07-21  60.8750  61.1875  60.375  61.0000  24.969595   75200     5
# 1999-07-22  60.9375  61.0000  60.625  60.8750  24.918421   33500     5

# %%
samples = list()
length = 200
# step over the 5,000 in jumps of 200
for i in range(0,int(len(hsbc)/length),length):
    # grab from i to i + 200
    sample = hsbc[i:i+length]
    samples.append(sample)
print(len(samples))
# Out:
# 1

# %%
time = np.linspace(0,20,1000)

amplitude_a = jpm['Close'][0:1000]
amplitude_b = cof['Close'][0:1000]
m = KnnDtw()
distance = m._dtw_distance(amplitude_a, amplitude_b)

fig = plt.figure(figsize=(12,4))
_ = plt.plot(time, amplitude_a, label='A')
_ = plt.plot(time, amplitude_b, label='B')
_ = plt.title('DTW distance between A and B is %.2f' % distance)
_ = plt.ylabel('Amplitude')
_ = plt.xlabel('Time')
_ = plt.legend()

# %%
jpm['Rate'].unique()
# Out:
# array([6, 5, 4, 3, 7], dtype=int64)

# %%
jpm_7 = jpm['Close'].loc[jpm['Rate'] == 7]
jpm_6 = jpm['Close'].loc[jpm['Rate'] == 6]
jpm_5 = jpm['Close'].loc[jpm['Rate'] == 5]
jpm_4 = jpm['Close'].loc[jpm['Rate'] == 4]
jpm_3 = jpm['Close'].loc[jpm['Rate'] == 3]

# %%
print(len(jpm_7),len(jpm_6),len(jpm_5),len(jpm_4),len(jpm_3))
# Out:
# 1163 463 750 2950 472

# %%
hsbc['Rate'].unique()
# Out:
# array([5, 4, 3], dtype=int64)

# %%
hsbc_5 = hsbc['Close'].loc[hsbc['Rate'] == 5]

# %%
hsbc_5 = hsbc_5[0:len(jpm_5)]
len(hsbc_5)
# Out:
# 750

# %%
time = np.linspace(0,20,750)

amplitude_a = jpm_5
amplitude_b = hsbc_5
m = KnnDtw()
distance = m._dtw_distance(amplitude_a, amplitude_b)

fig = plt.figure(figsize=(12,4))
_ = plt.plot(time, amplitude_a, label='A')
_ = plt.plot(time, amplitude_b, label='B')
_ = plt.title('DTW distance between A and B is %.2f' % distance)
_ = plt.ylabel('Amplitude')
_ = plt.xlabel('Time')
_ = plt.legend()

# %%
citi['Rate'].unique()
# Out:
# array([1, 2, 3, 5, 6, 4, 7], dtype=int64)

# %%
citi_5 = citi['Close'].loc[citi['Rate'] == 5]
citi_5 = citi_5[0:len(jpm_5)]

# %%
time = np.linspace(0,20,750)

amplitude_a = jpm_5
amplitude_b = citi_5
m = KnnDtw()
distance = m._dtw_distance(amplitude_a, amplitude_b)

fig = plt.figure(figsize=(12,4))
_ = plt.plot(time, amplitude_a, label='A')
_ = plt.plot(time, amplitude_b, label='B')
_ = plt.title('DTW distance between A and B is %.2f' % distance)
_ = plt.ylabel('Amplitude')
_ = plt.xlabel('Time')
_ = plt.legend()

# %%
ally_14 = ally['Close'].loc[ally['Rate'] == 14]
ally_13 = ally['Close'].loc[ally['Rate'] == 13] 

axp_5 = axp['Close'].loc[axp['Rate'] == 5] 
axp_6 = axp['Close'].loc[axp['Rate'] == 6] 
axp_7 = axp['Close'].loc[axp['Rate'] == 7] 

bac_2 = bac['Close'].loc[bac['Rate'] == 2]
bac_3 = bac['Close'].loc[bac['Rate'] == 3]
bac_4 = bac['Close'].loc[bac['Rate'] == 4]
bac_5 = bac['Close'].loc[bac['Rate'] == 5]
bac_6 = bac['Close'].loc[bac['Rate'] == 6]
bac_7 = bac['Close'].loc[bac['Rate'] == 7]
bac_8 = bac['Close'].loc[bac['Rate'] == 8]
bac_9 = bac['Close'].loc[bac['Rate'] == 9]

bbt_4 = bbt['Close'].loc[bbt['Rate'] == 4]
bbt_5 = bbt['Close'].loc[bbt['Rate'] == 5]
bbt_6 = bbt['Close'].loc[bbt['Rate'] == 6]

bbva_4 = bbva['Close'].loc[bbva['Rate'] == 4]
bbva_5 = bbva['Close'].loc[bbva['Rate'] == 5]
bbva_6 = bbva['Close'].loc[bbva['Rate'] == 6]
bbva_7 = bbva['Close'].loc[bbva['Rate'] == 7]
bbva_9 = bbva['Close'].loc[bbva['Rate'] == 9]
bbva_10 = bbva['Close'].loc[bbva['Rate'] == 10]
     
bcs_1 = bcs['Close'].loc[bcs['Rate'] == 1]
bcs_2 = bcs['Close'].loc[bcs['Rate'] == 2]
bcs_3 = bcs['Close'].loc[bcs['Rate'] == 3]
bcs_4 = bcs['Close'].loc[bcs['Rate'] == 4]
bcs_5 = bcs['Close'].loc[bcs['Rate'] == 5]
bcs_6 = bcs['Close'].loc[bcs['Rate'] == 6]

bk_1 = bk['Close'].loc[bk['Rate'] == 1]
bk_2 = bk['Close'].loc[bk['Rate'] == 2]
bk_3 = bk['Close'].loc[bk['Rate'] == 3]
bk_4 = bk['Close'].loc[bk['Rate'] == 4]
bk_5 = bk['Close'].loc[bk['Rate'] == 5]
bk_6 = bk['Close'].loc[bk['Rate'] == 6]

bku_10 = bku['Close'].loc[bku['Rate'] == 10]
bku_11 = bku['Close'].loc[bku['Rate'] == 11]

cfg_7 = cfg['Close'].loc[cfg['Rate'] == 7]
cfg_8 = cfg['Close'].loc[cfg['Rate'] == 8]
     
citi_1 = citi['Close'].loc[citi['Rate'] == 1] 
citi_2 = citi['Close'].loc[citi['Rate'] == 2] 
citi_3 = citi['Close'].loc[citi['Rate'] == 3] 
citi_4 = citi['Close'].loc[citi['Rate'] == 4] 
citi_5 = citi['Close'].loc[citi['Rate'] == 5] 
citi_6 = citi['Close'].loc[citi['Rate'] == 6] 
citi_7 = citi['Close'].loc[citi['Rate'] == 7] 

cof_7 = cof['Close'].loc[cof['Rate'] == 7] 
cof_8 = cof['Close'].loc[cof['Rate'] == 8] 
cof_10 = cof['Close'].loc[cof['Rate'] == 10] 
cof_11 = cof['Close'].loc[cof['Rate'] == 11] 

dfs_9 = dfs['Close'].loc[dfs['Rate'] == 9] 
dfs_10 = dfs['Close'].loc[dfs['Rate'] == 10]

fbp_9 = fbp['Close'].loc[fbp['Rate'] == 9]
fbp_11 = fbp['Close'].loc[fbp['Rate'] == 11]
fbp_12 = fbp['Close'].loc[fbp['Rate'] == 12]
fbp_14 = fbp['Close'].loc[fbp['Rate'] == 14]
fbp_16 = fbp['Close'].loc[fbp['Rate'] == 16]
fbp_17 = fbp['Close'].loc[fbp['Rate'] == 17]
fbp_18 = fbp['Close'].loc[fbp['Rate'] == 18]
     
fmbi_6 = fmbi['Close'].loc[fmbi['Rate'] == 6] 
fmbi_7 = fmbi['Close'].loc[fmbi['Rate'] == 7] 
fmbi_8 = fmbi['Close'].loc[fmbi['Rate'] == 8] 
fmbi_9 = fmbi['Close'].loc[fmbi['Rate'] == 9] 

gs_4 = gs['Close'].loc[gs['Rate'] == 4]
gs_5 = gs['Close'].loc[gs['Rate'] == 5]
gs_7 = gs['Close'].loc[gs['Rate'] == 7]
gs_8 = gs['Close'].loc[gs['Rate'] == 8]
     
hsbc_3 = hsbc['Close'].loc[hsbc['Rate'] == 3] 
hsbc_4 = hsbc['Close'].loc[hsbc['Rate'] == 4] 
hsbc_5 = hsbc['Close'].loc[hsbc['Rate'] == 5] 

jpm_3 = jpm['Close'].loc[jpm['Rate'] == 3]
jpm_4 = jpm['Close'].loc[jpm['Rate'] == 4]
jpm_5 = jpm['Close'].loc[jpm['Rate'] == 5]
jpm_6 = jpm['Close'].loc[jpm['Rate'] == 6]
jpm_7 = jpm['Close'].loc[jpm['Rate'] == 7]
     
ms_4 = ms['Close'].loc[ms['Rate'] == 4]
ms_5 = ms['Close'].loc[ms['Rate'] == 5]
ms_6 = ms['Close'].loc[ms['Rate'] == 6]
ms_7 = ms['Close'].loc[ms['Rate'] == 7]
ms_8 = ms['Close'].loc[ms['Rate'] == 8]
ms_9 = ms['Close'].loc[ms['Rate'] == 9]
     
pnc_5 = pnc['Close'].loc[pnc['Rate'] == 5]
pnc_6 = pnc['Close'].loc[pnc['Rate'] == 6]
pnc_7 = pnc['Close'].loc[pnc['Rate'] == 7]

schw_6 = schw['Close'].loc[schw['Rate'] == 6]
schw_7 = schw['Close'].loc[schw['Rate'] == 7]
     
snv_5 = snv['Close'].loc[snv['Rate'] == 5]
snv_6 = snv['Close'].loc[snv['Rate'] == 6]
snv_7 = snv['Close'].loc[snv['Rate'] == 7]
snv_11 = snv['Close'].loc[snv['Rate'] == 11]
snv_12 = snv['Close'].loc[snv['Rate'] == 12]
snv_13 = snv['Close'].loc[snv['Rate'] == 13]
snv_14 = snv['Close'].loc[snv['Rate'] == 14]
     
sti_4 = sti['Close'].loc[sti['Rate'] == 4]
sti_5 = sti['Close'].loc[sti['Rate'] == 5]
sti_8 = sti['Close'].loc[sti['Rate'] == 8]

stt_4 = stt['Close'].loc[stt['Rate'] == 4]
stt_5 = stt['Close'].loc[stt['Rate'] == 5]
stt_6 = stt['Close'].loc[stt['Rate'] == 6]
     
td_2 = td['Close'].loc[td['Rate'] == 2]
td_3 = td['Close'].loc[td['Rate'] == 3]
td_4 = td['Close'].loc[td['Rate'] == 4]
td_5 = td['Close'].loc[td['Rate'] == 5]
td_6 = td['Close'].loc[td['Rate'] == 6]
td_7 = td['Close'].loc[td['Rate'] == 7]
td_8 = td['Close'].loc[td['Rate'] == 8]
     
usb_3 = usb['Close'].loc[usb['Rate'] == 3]
usb_4 = usb['Close'].loc[usb['Rate'] == 4]
usb_5 = usb['Close'].loc[usb['Rate'] == 5]
usb_6 = usb['Close'].loc[usb['Rate'] == 6]
     
wfc_2 = wfc['Close'].loc[wfc['Rate'] == 2]
wfc_3 = wfc['Close'].loc[wfc['Rate'] == 3]
wfc_4 = wfc['Close'].loc[wfc['Rate'] == 4]
wfc_5 = wfc['Close'].loc[wfc['Rate'] == 5]
wfc_6 = wfc['Close'].loc[wfc['Rate'] == 6]

# %%
list_1 = [bcs_1, bk_1, citi_1]
list_2 = [bac_2, bcs_2, bk_2, citi_2, td_2]
list_3 = [bac_3, bcs_3, bk_3, citi_3, hsbc_3, jpm_3, td_3, usb_3]
list_4 = [bac_4, bbt_4, bbva_4, bcs_4, bk_4, citi_4, gs_4, hsbc_4, jpm_4, ms_4, sti_4, stt_4, td_4, usb_4]
list_5 = [axp_5, bac_5, bbt_5, bbva_5, bcs_5, bk_5, citi_5, gs_5, hsbc_5, jpm_5, ms_5, pnc_5, snv_5, sti_5, stt_5, td_5, usb_5]
list_6 = [axp_6, bac_6, bbt_6, bbva_6, bcs_6, bk_6, citi_6, fmbi_6, jpm_6, ms_6, pnc_6, schw_6, snv_6, stt_6, td_6, usb_6]
list_7 = [axp_7, bac_7, bbva_7, cfg_7, citi_7, cof_7, fmbi_7, gs_7, jpm_7, ms_7, pnc_7, schw_7, snv_7, td_7]
list_8 = [bac_8, cfg_8, cof_8, fmbi_8, gs_8, ms_8, sti_8, td_8]
list_9 = [bac_9, bbva_9, dfs_9, fbp_9, fmbi_9, ms_9]
list_10 = [bbva_10, bku_10, cof_10, dfs_10]
list_11 = [bku_11, cof_11, fbp_11, snv_11]
list_12 = [fbp_12, snv_12]
list_13 = [ally_13, snv_13]
list_14 = [ally_14, fbp_14, snv_14]
list_16 = [fbp_16]
list_17 = [fbp_17]
list_18 = [fbp_18]

# %%
for i in list_1:
    for j in list_1:
        time = np.linspace(0,20,min(len(i),len(j)))
        if len(i) > len (j):
            amplitude_a = i[0:len(j)]
            amplitude_b = j
        else:
            amplitude_a = i
            amplitude_b = j[0:len(i)]   
        m = KnnDtw()
        distance = m._dtw_distance(amplitude_a, amplitude_b)
        print(distance)
# Out:
# 0.0
# 32817.985714999995
# 155631.42193700004
# 32817.985714999995
# 0.0
# 143337.23379999996
# 155631.42193700004
# 143337.23379999996
# 0.0

# %%
x_train = np.array(bk.iloc[:, :-1])
y_train = np.array(bk['Rate'])
x_test = np.array(wfc.iloc[:, :-1])
y_test = np.array(wfc['Rate'])

# %%
m = KnnDtw(n_neighbors=1, max_warping_window=10)
m.fit(x_train[::100], y_train[::100])
label, proba = m.predict(x_test[::100])

# %%
from sklearn.metrics import classification_report, confusion_matrix

labels = {21:'C',20:'Ca',19:'Caa3',18:'Caa2',17:'Caa1',16:'B3',15:'B2',14:'B1',13:'Ba3',12:'Ba2',11:'Ba1',10:'Baa3',9:'Baa2',8:'Baa1',7:'A3',6:'A2',5:'A1',4:'Aa3',3:'Aa2',2:'Aa1',1:'Aaa'}
print(classification_report(label, y_test[::100],
                            target_names=[l for l in labels.values()]))

conf_mat = confusion_matrix(label, y_test[::100])

fig = plt.figure(figsize=(6,6))
width = np.shape(conf_mat)[1]
height = np.shape(conf_mat)[0]

res = plt.imshow(np.array(conf_mat), cmap=plt.cm.summer, interpolation='nearest')
for i, row in enumerate(conf_mat):
    for j, c in enumerate(row):
        if c>0:
            plt.text(j-.2, i+.1, c, fontsize=16)
            
cb = fig.colorbar(res)
plt.title('Confusion Matrix')
_ = plt.xticks(range(6), [l for l in labels.values()], rotation=90)
_ = plt.yticks(range(6), [l for l in labels.values()])
# Out:
#              precision    recall  f1-score   support
#
#           C       0.00      0.00      0.00        40
#          Ca       0.29      0.50      0.36         8
#        Caa3       0.00      0.00      0.00         8
#        Caa2       0.00      0.00      0.00         0
#        Caa1       0.00      0.00      0.00         2
#          B3       0.00      0.00      0.00         0
#
# avg / total       0.04      0.07      0.05        58
# C:\Users\ADMIN\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1428: UserWarning: labels size, 6, does not match size of target_names, 21
#   .format(len(labels), len(target_names))
# C:\Users\ADMIN\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...
